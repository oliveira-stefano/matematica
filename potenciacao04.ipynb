# %% [markdown]
# # Potenciação

# %% [markdown]
# ## Definição
#
# Seja a um numero real e n um numero natural, com n > 2.
# A potência de base a e expoente n é o número a**n tal que:
# $$^{n}a =  \frac{a * a * a * a ...}{n fatores}$$
#
# $$ ^{4}a = a.a.a.a

# %% [markdown]
# ## Exemplos
#
# * 1 (-5)**2 = (-5) . (-5) = 25
# * 2 -5**2 = -5 . 5 = - 25

# %%
print((-5) ** 2)
print(- 5 ** 2)
from fractions import Fraction
print(Fraction(3,2)**2)
print(- Fraction(3,2)**3)
# Out:
# 25
# -25
# 9/4
# -27/8
