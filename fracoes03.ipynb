# %% [markdown]
# # Fraçao

# %% [markdown]
# Fração é a representação matemática das partes de determinada quantidade dividida em pedaços ou fragmentos iguais.
#
# As frações são úteis em várias situações, principalmente para representar algo que não conseguimos apresentar por números naturais.
#
# Vamos utilizar como exemplo a seguinte situação:
#
# Maria comprou uma pizza e dividiu em 4 fatias iguais. Como não estava com muita fome, ela comeu apenas uma fatia. Que fração da pizza Maria conheceu?
#
# Vemos no texto acima que das 4 fatias de pizza que Maria tinha, ela comeu apenas uma, ou seja, 1 de 4. Isso pode ser escrito como uma fração: $$\frac{1}{4}$$
#
#
#
# No nosso exemplo, o número 1 representa o numerador da fração e indica quantas partes foram tomadas. Já número 4, representa o denominador da fração e
# indica em quantas partes o todo foi dividida.

# %% [markdown]
# *Notacao*

# %% [markdown]
# $$\frac{numerador}{denominador}$$

# %% [markdown]
# ## Fracao propria

# %% [markdown]
# numerador < denominador

# %% [markdown]
# ## Fração impropria

# %% [markdown]
# numerador > denominador

# %% [markdown]
# ## Fração equivalente

# %% [markdown]
# Fracoes equivalentes sao fracoes que representam a mesma parte do todo.

# %% [markdown]
# Como sabemos se duas frações são equivalentes?
#
# São equivalentes se os produtos do numerador de uma e o denominador da outra são iguais, ou seja, produtos cruzados.
#
# Vamos ver uns exemplos:
#
# Vamos ver se 2/5 e 4/10 são equivalentes. 4/10 simplificando por 2 = 2/5. Ou seja são equivalentes

# %% [markdown]
# ### Numero misto

# %% [markdown]
# $$3\frac{1}{2}$$
#
# O 3 nao esta multiplicando o valor 1. O 3  uma parte inteira e o 1/2 eh um numero fracional.
# 3 1/2 = 3 + 1/2

# %%
from fractions import Fraction
f1 = Fraction(8, 3)
f2 = Fraction(6, 5)
f3 = Fraction(7, 12)

3 * (((Fraction(2,3) - Fraction(4,5)) * Fraction(15,8)) + Fraction(4,9) / Fraction(2,3))
# Out:
# Fraction(5, 4)

# %% [markdown]
# ### Exercicio

# %%
from fractions import Fraction
#Fraction(2,3) + Fraction(4,3) - Fraction(11,3)
#Fraction(6,7)*Fraction(1,3)+(2 * (3 + Fraction(1,3) - 2)) / 5
Fraction(1,2) - Fraction(4,9) + 2 + 4 + Fraction(6,7) - 1 + 11 + Fraction(1,2)
# Out:
# Fraction(1097, 63)

# %%
print((-5)**2)
print(-5**2)
print(Fraction(3,2)**2)
print(2**-2)
print(-(Fraction(1,2))**-4)
print(Fraction((2 * 3**6 + 3**7) , (3**4-3*3**5)))
print((2 * 3**6 + 3**7) / (3**4-3*3**5))
print(4**3000 < 3**4000)
print((-2**3)**2 == (-2**2)**3)
print(5**8 * 4**3)
print(Fraction(6**4, 2**6) == Fraction(9, 2)**2)
print(Fraction(6**4, 4*3**4) == 2)
print(-8**1/3)
# Out:
# 25
# -25
# 9/4
# 0.25
# -16
# -45/8
# -5.625
# True
# False
# 25000000
# True
# False
# -2.6666666666666665
